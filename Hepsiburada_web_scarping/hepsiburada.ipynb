# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import numpy as np

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36 OPR/113.0.0.0"}
a = 1
r = requests.get("https://www.hepsiburada.com/ara?q=gamer&sayfa="+str(a)+"" , headers=headers)
soup = BeautifulSoup(r.content , "lxml")

st1 = soup.find("div" , attrs = {"class" : "productListContent-tEA_8hfkPU5pDSjuFdKG"})
st2 = st1.find("ul" ,attrs = {"class" : "productListContent-frGrtf5XrVXRwJ05HUfU productListContent-rEYj2_8SETJUeqNhyzSm"})
st3 = st2.find_all("li" , attrs = {"class" : "productListContent-zAP0Y5msy8OHn5z7T_K_"})

liste= []
while a <= 50:

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36 OPR/113.0.0.0"}

    r = requests.get("https://www.hepsiburada.com/ara?q=gamer&sayfa="+str(a)+"" , headers=headers)
    soup = BeautifulSoup(r.content , "lxml")
    for i in st3:
        link_end = i.a.get("href")
        link_start = "https://www.hepsiburada.com/"
        link = link_start + link_end
        print(link)
            
        r1 = requests.get(link , headers=headers)
        soup1 = BeautifulSoup(r1.content , "lxml")
        r1
            
        try:
            Title = soup1.find("h1" , attrs= {"class" : "xeL9CQ3JILmYoQPCgDcl"}).text.strip()
            Salesman = soup1.find("span" , attrs= {"class" : "rzVCX6O5Vz9bkKB61N2W"}).text.strip()
            Evaluation = soup1.find("a" , attrs= {"class" : "yPPu6UogPlaotjhx1Qki"}).text.strip()
            Rating = soup1.find("span" , attrs= {"class" : "JYHIcZ8Z_Gz7VXzxFB96"}).text.strip()
            Price = soup1.find("div" , attrs= {"data-test-id" : "price-current-price"}).text.strip()
        except:
            Price = np.nan
            Salesman = np.nan
            Rating = np.nan
            Evaluation = np.nan
            Title = np.nan
            
        liste.append([Title , Salesman , Rating , Evaluation , Price])
    a  = a + 1
    


df = pd.DataFrame(liste)
df.columns = ["Title" , "Salesman" , "Rating" , "Evaluation" , "Price"]
print(df.shape)
df.head()


df.to_excel("hepsiburada_gamer.xlsx", index=False)
# Out:
# https://www.hepsiburada.com//izoly-m110-i5-3350-16gb-256gb-ssd-masaustu-bilgisayar-pm-bdizoh110
# https://www.hepsiburada.com//izoly-k303-i7-860-16gb-256gb-gt-740-27-oyuncu-masaustu-bilgisayari-pm-HB000004KBYF
# https://www.hepsiburada.com/https://adservice.hepsiburada.com/event/api/v1/track?event=...&redirect=https%3A%2F%2Fwww.hepsiburada.com%2Fgameline-gl-16-ryzen-5-8400f-32gb-ddr5-1tb-ssd-rtx4060ti-8gb-sivi-sogutmali-oyuncu-masaustu-bilgisayar-p-HBCV00006WYP15%3Fmagaza%3Dmetsabilisim&eventName=sp-click&platform=desktop
# https://www.hepsiburada.com/https://adservice.hepsiburada.com/event/api/v1/track?event=...&redirect=https%3A%2F%2Fwww.hepsiburada.com%2Fgameline-gx08-ryzen-5-8400f-32gb-ddr5-1tb-ssd-rtx4060-8gb-27-240hz-pivot-masaustu-oyuncu-bilgisayari-p-HBCV0000707VB2%3Fmagaza%3Dmetsabilisim&eventName=sp-click&platform=desktop
# ...
